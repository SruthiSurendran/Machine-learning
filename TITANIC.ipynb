# %%
# TITANIC DATA

# %%
import seaborn as sns
import pandas as pd

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
sns.countplot(df['survived'],palette='autumn')##Just by observing the graph,survivel rate is less .
# Out:
# C:\Users\Hrishikesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
sns.countplot(df['sex'],palette='autumn')
##Just by observing the graph, it can be approximated that the survival rate of men is around 70% and that of women is around 20%.
# Out:
# C:\Users\Hrishikesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.pairplot(df,hue='survived',diag_kind='kde',palette='autumn')##in P class vs survived:higher class passengers had more survival rate ,higher class passengers have higher survivel rate compared to other class.

# %%
sns.pairplot(df,hue='sex',diag_kind='kde',palette='autumn')##sex vs survied:survival rate of men is higher than women .
# Out:
# C:\Users\Hrishikesh\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
